# %%
# venv: uacademia

# %%
# ### Paso 1: Cargar las librerías y el Dataset
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
# Cargar el dataset directamente desde Seaborn

df = sns.load_dataset('diamonds')
print(f"El dataset contiene {df.shape[0]} filas y {df.shape[1]} columnas.")
print()
df.head()
# Out:
# El dataset contiene 53940 filas y 10 columnas.
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# ---

# %%
# ### Paso 2: Análisis Exploratorio Inicial (Identificando Imposibles)
# Las variables `x`, `y`, `z` representan las dimensiones en milímetros del diamante. 
# ¿Puede un diamante a la venta medir 0 mm de ancho, largo o profundidad?
# Out:
# Valores mínimos en las dimensiones:
# x    0.0
# y    0.0
# z    0.0
# dtype: float64

# %%
# **Limpieza:** Filtremos el DataFrame para eliminar estos errores obvios.
# Out:
# Filas restantes tras eliminar dimensiones en cero: 53920

# %% [markdown]
# ---

# %%
# ### Paso 3: Visualización de Outliers Naturales (El Mercado del Lujo)
# Ahora analizaremos el precio (`price`) y los quilates (`carat`). Vamos a generar un gráfico de caja (Boxplot).

# %% [markdown]
# ### **Análisis:** Verás una enorme cantidad de puntos negros individuales a la derecha del "bigote".
#
# #### Estos son outliers **naturales**: diamantes extremadamente raros, grandes y costosos que legítimamente rompen el comportamiento del mercado estándar.

# %% [markdown]
# ---

# %%
# ### Paso 4: Detección Matemática usando el Rango Intercuartílico (IQR)
# Vamos a aislar matemáticamente los diamantes que tienen un precio "atípico" utilizando la regla del IQR.

# 1. Calcular los cuartiles Q1 y Q3

# %%
# 2. Calcular el IQR (Rango Intercuartílico)
IQR = Q3 - Q1

# %%
# 3. Definir los límites 


print(f"Rango intercuartílico (IQR): {IQR}")
print(f"Límite superior para detectar outliers: {limite_superior} USD")
# Out:
# Rango intercuartílico (IQR): 4374.25
# Límite superior para detectar outliers: 11884.625 USD

# %% [markdown]
# ---

# %%
# ### Paso 5: Separación y Toma de Decisiones
# Vamos a dividir nuestro dataset en dos: los diamantes "estándar" y los "outliers de lujo".
# Out:
# Cantidad de diamantes estándar: 50388
# Cantidad de diamantes considerados 'Outliers' por precio: 3532

# %% [markdown]
# ### Desafío Final:

# %%
# Grafica un Scatterplot de `carat` (quilates) vs `price` (precio) usando `df_normales`.

# %%
# Grafica un Scatterplot de `carat` (quilates) vs `price` (precio) usando ` `df_clean`.

# %% [markdown]
# ### ¿Cómo cambió la forma de la distribución y la escala del gráfico al remover los outliers?
