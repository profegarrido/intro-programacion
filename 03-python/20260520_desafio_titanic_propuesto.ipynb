# %%
# env uacademia

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](
# https://colab.research.google.com/github/profegarrido/intro-programacion/blob/master/03-python/20260520_desafio_titanic_propuesto.ipynb)

# %% [markdown]
# # No te hundas con el Titanic!!!

# %% [markdown]
# ![](https://i.blogs.es/3f9830/titanic-ancla/1366_2000.jpeg)

# %% [markdown]
# ## dataset del Titanic [Descargar](https://drive.google.com/uc?export=download&id=1j-Fs8EwLgMpAL_CycDbc018H-J2mVD7P)

# %% [markdown]
# ### Preguntas a responder
# <ol>
#   <li>Listar los 7 últimos datos del dataframe</li>
#   <li>¿Cuántas filas y columnas tiene el dataframe? (mejorado)</li>
#     <ol>
#       <li>Nivel Basico</li>
#       <li>Nivel Medio</li>
#       <li>Nivel Avanzado</li>
#     </ol>
#   <li>Listar las columnas del dataframe</li>
#     <ol>
#       <li>Nivel Basico</li>
#       <li>Nivel Avanzado</li>
#     </ol>
#   <li>¿Cuáles son los tipos de datos de las columnas?</li>
#     <ol>
#       <li>Opción 1</li>
#       <li>Opción 2</li>
#     </ol>
#   <li>¿El dataframe está completo?</li>
#     <ol>
#       <li>¿Cuál es el campo con menos datos? ¿A qué porcentaje corresponde?</li>
#     </ol>
#   <li>Eliminarias columnas. ¿Cuáles?</li>
#   <li>Cambia el nombre de las columnas a nombres en español</li>
#   <li>¿Cuál era la edad menor y mayor de los pasajeros del dataframe?</li>
#     <ol>
#       <li>Opción Básica</li>
#       <li>Opción Máster</li>
#     </ol>
#   <li>¿Cuál era el precio menor y mayor de los boletos del Titanic?</li>
#     <ol>
#       <li>Opción Básica</li>
#       <li>Opción Máster</li>
#     </ol>
# </ol>

# %%
# Importar librerias
import pandas as pd

# %%
# leer set de datos
df =

# %% [markdown]
# #### 1. Listar los 7 últimos datos del dataframe

# %% [markdown]
# #### 2. ¿Cuántas filas y columnas tiene el dataframe? (mejorado)
# ##### Nivel Basico

# %% [markdown]
# ##### Nivel Medio

# %% [markdown]
# ##### Nivel Avanzado

# %% [markdown]
# #### 3. Listar las columnas del dataframe
# ##### Nivel Basico

# %% [markdown]
# ##### Nivel Avanzado

# %% [markdown]
# #### 4. ¿Cuáles son los tipos de datos de las columnas?
# ##### Opción 1

# %% [markdown]
# ##### Opción 2

# %% [markdown]
# #### 5. ¿El dataframe está completo?
# ##### ¿Cuál es el campo con menos datos?
# ##### ¿A qué porcentaje corresponde?

# %% [markdown]
# <table>
#         <thead>
#             <tr>
#                 <th>Variable</th>
#                 <th>Nombre en Dataset</th>
#                 <th>Descripción</th>
#                 <th>Tipo de Dato</th>
#             </tr>
#         </thead>
#         <tbody>
#             <tr>
#                 <td>Identificador</td>
#                 <td>PassengerId</td>
#                 <td>Código único para cada pasajero.</td>
#                 <td>Numérico</td>
#             </tr>
#             <tr>
#                 <td>Sobrevivio</td>
#                 <td>Survived</td>
#                 <td>Variable objetivo: \(0\) = No sobrevivió; \(1\) = Sobrevivió.</td>
#                 <td>Categórico/Binario</td>
#             </tr>
#             <tr>
#                 <td>Clase</td>
#                 <td>Pclass</td>
#                 <td>Clase socioeconómica del pasajero: \(1\) = Primera, \(2\) = Segunda, \(3\) = Tercera.</td>
#                 <td>Numérico/Ordinal</td>
#             </tr>
#             <tr>
#                 <td>Nombre</td>
#                 <td>Name</td>
#                 <td>Nombre completo y títulos (ej. Mr., Mrs., Miss) del pasajero.</td>
#                 <td>Texto</td>
#             </tr>
#             <tr>
#                 <td>Sexo</td>
#                 <td>Sex</td>
#                 <td>Género del pasajero (male / female).</td>
#                 <td>Categórico</td>
#             </tr>
#             <tr>
#                 <td>Edad</td>
#                 <td>Age</td>
#                 <td>Edad en años (los bebés pueden tener valores decimales).</td>
#                 <td>Numérico</td>
#             </tr>
#             <tr>
#                 <td>Hermanos/Cónyuges</td>
#                 <td>SibSp</td>
#                 <td>Cantidad de hermanos, hermanastros, esposos o esposas a bordo.</td>
#                 <td>Numérico</td>
#             </tr>
#             <tr>
#                 <td>Padres/Hijos</td>
#                 <td>Parch</td>
#                 <td>Cantidad de padres, madres, hijos o hijastros a bordo.</td>
#                 <td>Numérico</td>
#             </tr>
#             <tr>
#                 <td>Boleto</td>
#                 <td>Ticket</td>
#                 <td>Número del billete de embarque.</td>
#                 <td>Texto</td>
#             </tr>
#             <tr>
#                 <td>Tarifa</td>
#                 <td>Fare</td>
#                 <td>Precio pagado por el pasaje en libras esterlinas.</td>
#                 <td>Numérico</td>
#             </tr>
#             <tr>
#                 <td>Cabina</td>
#                 <td>Cabin</td>
#                 <td>Número de ubicación de la cabina del pasajero.</td>
#                 <td>Texto</td>
#             </tr>
#             <tr>
#                 <td>Embarcado</td>
#                 <td>Embarked</td>
#                 <td>Puerto donde subió al barco: \(C\) = Cherbourg, \(Q\) = Queenstown, \(S\) = Southampton.</td>
#                 <td>Categórico</td>
#             </tr>
#         </tbody>
#     </table>

# %% [markdown]
# #### 6. Eliminarias columnas. ¿Cuáles?

# %% [markdown]
# #### 7. Cambia el nombre de las columnas a nombres en español

# %% [markdown]
# #### 8. ¿Cuál era la edad menor y mayor de los pasajeros del dataframe?

# %% [markdown]
# ##### Opción Básica

# %% [markdown]
# ##### Opción Máster

# %% [markdown]
# #### 9. ¿Cuál era el precio menor y mayor de los boletos del Titanic?
# ##### Opción Básica

# %% [markdown]
# ##### Opción Máster

# %% [markdown]
# ## Información gráfica

# %%
# Importar librerias
import matplotlib.pyplot as plt

# %% [markdown]
# <ol>
#   <li>Gráficar en barras columnas y su contenido total</li>
#     <ol>
#       <li>Nivel Basico</li>
#       <li>Nivel Avanzado: a las barras menor al total colorear de rojo, el resto de gris</li>
#     </ol>
#   <li>Gráficar cantidad de supervivientes y fallecidos</li>
#     <ol>
#       <li>Nivel Basico</li>
#       <li>Nivel Medio: usar etiquetas (sobrevivio, no sobrevivio), agregar porcentaje, sin decimales</li>
#     </ol>
#   <li>¿Qué gráfico usaría para mostar la proporción mujeres/hombres? Construyalo</li>
#   <li>Realizar un gráfico de barras horizontal según la edad de los pasajeros del Titanic</li>
#     <ol>
#       <li>Niños: 0 a 14 años</li>
#       <li>Jóvenes: 15 a 24 años</li>
#       <li>Adultos: 25 a 64 años</li>
#       <li>Adultos Mayores: Más de 65 años</li>
#     </ol>
#   <li>Gráficar el histograma de la Tarifa</li>
#   <li>Crear un set de gráficos de torta (subplot), usar leyendas coherentes</li>
#     <ol>
#       <li>Según la clase del pasajero</li>
#       <li>Según la clase del pasajero y si sobrevivio</li>
#       <li>Según la clase del pasajero y si No sobrevivio</li>
#     </ol>
# </ol>

# %% [markdown]
# #### 1. Gráficar en barras columnas y su contenido total
# ##### Nivel Basico

# %%
# Crear el gráfico

# %% [markdown]
# ##### Nivel Avanzado: a las barras menor al total colorear de rojo, el resto de gris

# %%
# Crear el gráfico

# %% [markdown]
# #### 2. Gráficar cantidad de supervivientes y fallecidos
# ##### Nivel Basico

# %% [markdown]
# ##### Nivel Medio: usar etiquetas (sobrevivio, no sobrevivio), agregar porcentaje, sin decimales

# %% [markdown]
# #### 3. ¿Qué gráfico usaría para mostar la proporción mujeres/hombres? Construyalo

# %% [markdown]
# #### 4. Realizar un gráfico de barras horizontal según la edad de los pasajeros del Titanic
#
# - Niños: 0 a 14 años
# - Jóvenes: 15 a 24 años
# - Adultos: 25 a 64 años
# - Adultos Mayores: Más de 65 años

# %%
# Crear el gráfico de barras

# %% [markdown]
# #### 5. Gráficar el histograma de la Tarifa

# %% [markdown]
# #### 6. Crear un set de gráficos de torta (subplot), usar leyendas coherentes
#
# - Según la clase del pasajero
# - Según la clase del pasajero y si sobrevivio
# - Según la clase del pasajero y si No sobrevivio
